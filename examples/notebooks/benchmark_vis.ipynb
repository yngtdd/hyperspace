# %%
import numpy as np
from hyperspace.benchmarks import StyblinskiTang

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
nx, ny = (50, 50)
x = np.linspace(-5, 5, nx)
y = np.linspace(-5, 5, ny)
xx, yy = np.meshgrid(x, y)

# %%
z = np.sin(xx**2 + yy**2) / (xx**2 + yy**2)
xx.shape
# Out:
# (50, 50)

# %%
h = plt.contourf(x,y,z)

# %%
stybtang = StyblinskiTang(2)

z = []
for step in range(len(x)):
    x_step = x[step]
    y_step = y[step]
    z.append(stybtang([x_step, y_step]))
    
z = np.asarray(z)

# %%
z.shape
# Out:
# (50,)

# %%
from mpl_toolkits.mplot3d import Axes3D

z = np.asarray(z)

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(x, y, z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-85b2b4d5199a> in <module>()
#       5 fig = plt.figure()
#       6 ax = fig.gca(projection='3d')
# ----> 7 ax.plot_surface(x, y, z)
#
# ~/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1634
#    1635         if Z.ndim != 2:
# -> 1636             raise ValueError("Argument Z must be 2-dimensional.")
#    1637         # TODO: Support masked arrays
#    1638         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Axes3D.plot_wireframe(X=x,Y=y,Z=z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e19b4d794e43> in <module>()
#       4 fig = plt.figure()
#       5 ax = fig.add_subplot(111, projection='3d')
# ----> 6 Axes3D.plot_wireframe(X=x,Y=y,Z=z)
#
# TypeError: plot_wireframe() missing 1 required positional argument: 'self'

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(xx, yy, response, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5e63b53597ea> in <module>()
#       8
#       9 ax.plot_surface(xx, yy, response, rstride=1, cstride=1, cmap=cm.coolwarm)
# ---> 10 plt.plot()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# TypeError: plot() missing 2 required positional arguments: 'xs' and 'ys'
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
z.shape
# Out:
# (50,)

# %%
response = np.empty([len(z), len(z)])

# %%
response[0] = z
response[1] = z

# %%
# Out:
# (50, 50)
