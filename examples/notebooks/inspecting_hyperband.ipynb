# %%
from skopt import load
from hyperspace.kepler.plots import plot_convergence

import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

# %matplotlib inline

# %%
results_path = '/Users/yngtodd/src/maintain/hyperspace/examples/results/hyperband/gbm_regressors/hyperband_gbm.pkl'
res = load(results_path)

# %%
def objective():
    pass

# %%
plot_convergence(res)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1133da710>)
