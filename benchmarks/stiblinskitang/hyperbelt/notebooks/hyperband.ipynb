# %%
from hyperspace.kepler import load_results
from hyperspace.kepler.plots import plot_convergence

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
resultspath = '../results/stybtang5'
results = load_results(resultspath)

# %%
res0 = results[0]

# %%
res0
# Out:
#           fun: -82.431784236673811606
#     func_vals: array([-82.43178424], dtype=float128)
#        models: []
#  random_state: <mtrand.RandomState object at 0x10a7a73a8>
#         space: Space([Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity')])
#         specs: {'args': {'n_jobs': 1, 'kappa': 1.96, 'xi': 0.01, 'n_restarts_optimizer': 5, 'n_points': 10000, 'callback': None, 'verbose': False, 'random_state': 0, 'y0': None, 'x0': [[1.7100502829606907, 3.755692199872777, 2.0029842471950308, 2.992997063243503, 3.25395409203698]], 'acq_optimizer': 'sampling', 'acq_func': 'EI', 'n_random_starts': -1, 'n_calls': 0, 'base_estimator': 'dummy', 'dimensions': Space([Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity'),
#        Real(low=-1.25, high=5.0, prior='uniform', transform='identity')]), 'func': Styblinski-Tang function defined over xi ∈ [-5.0, 5.0] for all i = 1, …, 5.}, 'function': 'base_minimize'}
#             x: [1.7100502829606907, 3.755692199872777, 2.0029842471950308, 2.992997063243503, 3.25395409203698]
#       x_iters: [[1.7100502829606907, 3.755692199872777, 2.0029842471950308, 2.992997063243503, 3.25395409203698]]

# %%
fig=plt.figure(figsize=(12, 12), dpi= 80, facecolor='w', edgecolor='k')
plot_convergence(results[0])
